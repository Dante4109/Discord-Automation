# %%
print("Hello world")

# %%
friends = 8
handshakes = 45
count = 0

for i in range (handshakes):
  handshakes = handshakes - 2
  count = count + 1
  print(handshakes)
print(count)

# %%
friends = [1,2,3,4,5,6,7,8,9]
handshakes = 0

for i in range(1, 11):
  for j in range(1, 11):
    if i < j:
      print(f"friend {i} shook hands with friend {j}")
      handshakes = handshakes + 1
print(handshakes)
# Out:
# friend 1 shook hands with friend 2
# friend 1 shook hands with friend 3
# friend 1 shook hands with friend 4
# friend 1 shook hands with friend 5
# friend 1 shook hands with friend 6
# friend 1 shook hands with friend 7
# friend 1 shook hands with friend 8
# friend 1 shook hands with friend 9
# friend 1 shook hands with friend 10
# friend 2 shook hands with friend 3
# friend 2 shook hands with friend 4
# friend 2 shook hands with friend 5
# friend 2 shook hands with friend 6
# friend 2 shook hands with friend 7
# friend 2 shook hands with friend 8
# friend 2 shook hands with friend 9
# friend 2 shook hands with friend 10
# friend 3 shook hands with friend 4
# friend 3 shook hands with friend 5
# friend 3 shook hands with friend 6
# friend 3 shook hands with friend 7
# friend 3 shook hands with friend 8
# friend 3 shook hands with friend 9
# friend 3 shook hands with friend 10
# friend 4 shook hands with friend 5
# friend 4 shook hands with friend 6
# ...

# %%
Door1 = "safe"
Door2 = "doom"
Guard1 = "truth"
Guard2 = "liar"

# ask guard 1 does this door lead to safey
# yes

# ask guard 2 does this door lead to safey
# yes



# ask guard 1 wich door would guard 2 say leads to safety
# door 2

# ask guard 2 wich door would guard 1 say leads to safety
# door 2


# ask guard 1 what guard 2 would say which door is the safe door
# guard 1 will say that guard 2 would say door 2 is safe 

# ask guard 2 what guard 1 would say which door is the safe door
# guard 2 will say that guard 1 would say door 2 is safe


Door1 = "doom"
Door2 = "safe"
Guard1 = "truth"
Guard2 = "liar"

# ask guard 1 wich door would guard 2 say leads to safety
# door 1

# ask guard 2 wich door would guard 1 say leads to safety
# door 2

# ask guard 1 what guard 2 would say which door is the safe door
# guard 1 will say that guard 2 would say door 1 is safe 

# ask guard 2 what guard 1 would say which door is the safe door
# guard 2 will say that guard 1 would say door 1 is safe

Door1 = "safe"
Door2 = "doom"
Guard1 = "liar"
Guard2 = "truth"

Door1 = "doom"
Door2 = "safe"
Guard1 = "liar"
Guard2 = "truth"
